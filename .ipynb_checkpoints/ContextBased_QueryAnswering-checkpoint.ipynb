# %% [markdown]
# ### Import Necessary Libraries

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk


import contractions

from string import digits

import re

import pymongo

import gensim

from glob import glob

from bs4 import BeautifulSoup

from bson.objectid import ObjectId

from tqdm import tqdm
from operator import itemgetter
import time
import os, multiprocessing, time
from gensim import corpora, models
from pprint import pprint
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans
from time import time
import matplotlib.pyplot as plt
import numpy as np
import operator
import warnings

from gensim.models import LsiModel
from collections import defaultdict
from configparser import ConfigParser
from gensim import corpora, models, similarities
from gensim.models import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel

nltk.download('stopwords')
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Functions Used

# %%
def clean_text(text):
    
    text = text.lower()
    
    remove_digits = str.maketrans('', '', digits)

    res = str(text).translate(remove_digits)

    text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

    text = strip_html_tags(text)
    
    cont = [contractions.fix(tok) for tok in text.split()]
    
    text = ' '.join([word for word in cont if not word.isdigit()])

    text = re.sub(' +',' ',res)
        
    tokenizer = RegexpTokenizer(r'\w+')
    
    tokens = tokenizer.tokenize(text)
    
    unigrams = [ t for t in tokens if len(t)==1]
    bigrams  = [t for t in tokens if len(t)==2]
    
    stop_list=stopwords.words('english')+unigrams+bigrams
    
    clean = [token for token in tokens if token not in stop_list]
    
    
    return ' '.join(clean)

# %%
def strip_html_tags(text):
    """remove html tags from text"""
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text(separator=" ")
    return stripped_text

# %%
def get_docs_per_topic(model):
    all_topics = model.print_topics()
    
    docs_per_topic = [[] for _ in all_topics]
    
    for doc_id, doc_bow in enumerate(corpus):
        doc_topics = model.get_document_topics(doc_bow)
        
        for topic_id, score in doc_topics:
            docs_per_topic[topic_id].append((doc_id, score))
    return docs_per_topic

# %%
def get_answer_lda(q_text,docs_per_topic, file_path):
    
    lda_model =  models.LdaModel.load(file_path)
    
    docs_per_topic = get_docs_per_topic(lda_model)
    
    dictionary = corpora.Dictionary.load("stack_of.dict")
    
    unseen_doc = dictionary.doc2bow(clean_text(q_text).split(" "))
    
    vector = lda_model[unseen_doc]
    
    vector.sort(key=itemgetter(1), reverse=True)
    
    topic_id = vector[0][0]
    
    doc_id = docs_per_topic[topic_id][0][0]
    
    conn = pymongo.MongoClient("mongodb://localhost:27017/")

    db = conn['stack_overflow']

    ques_col = db.get_collection('questions')
    
    docs = ques_col.find({}, no_cursor_timeout=True).limit(5000)
    
    for doc in docs:
        for token in doc['clean_aa'].split(" "):
            token_frequency[token] += 1
        
    docs = ques_col.find({}, no_cursor_timeout=True).limit(5000)
    
    documents = [ [token for token in doc['clean_aa'].split(" ") if token_frequency[token] > 1]
                for doc in docs  ]
    
    answer = ques_col.find_one({ "clean_aa": ' '.join(documents[doc_id])})['accepted_answer']
    
    return answer

# %%
def get_answer_lsa(q_text,docs_per_topic,lsi, file_path):
    
    lda_model =  models.LdaModel.load(file_path)
    
    docs_per_topic = get_docs_per_topic(lda_model)
    
    dictionary = corpora.Dictionary.load("stack_of.dict")
    
    unseen_doc=clean_text(q_text).split(" ")
    
    new_vec = dictionary.doc2bow(unseen_doc)
    
    vec_bow_tfidf = tfidf[new_vec]
    
    vector = lsi[vec_bow_tfidf]

    vector.sort(key=itemgetter(1), reverse=True)
    
    topic_id = vector[0][0]
    
    doc_id = docs_per_topic[topic_id][0][0]
    
    conn = pymongo.MongoClient("mongodb://localhost:27017/")

    db = conn['stack_overflow']

    ques_col = db.get_collection('questions')
    
    docs = ques_col.find({}, no_cursor_timeout=True).limit(5000)
    
    for doc in docs:
        for token in doc['clean_aa'].split(" "):
            token_frequency[token] += 1
        
    docs = ques_col.find({}, no_cursor_timeout=True).limit(5000)
    
    documents = [ [token for token in doc['clean_aa'].split(" ") if token_frequency[token] > 1]
                for doc in docs  ]
    
    answer = ques_col.find_one({ "clean_aa": ' '.join(documents[doc_id])})['accepted_answer']

    return answer

# %%
def get_lsa_topics(svd, terms, n_components, n_out = 7, n_weight = 5, topic = None):
    if topic is None:
        for k in range(n_components):
            idx = {i:abs(j) for i, j in enumerate(svd.components_[k])}
            sorted_idx = sorted(idx.items(), key=operator.itemgetter(1), reverse=True)
            weight = np.mean([ item[1] for item in sorted_idx[0:n_weight] ])
            print("T%s)" % k, end =' ')
            for item in sorted_idx[0:n_out-1]:
                print( " %0.3f*%s"  % (item[1] , terms[item[0]]) , end=' ')
            print()
    else:
        m = max(svd.components_[topic])
        idx = {i:abs(j) for i, j in enumerate(svd.components_[topic])}
        sorted_idx = sorted(idx.items(), key=operator.itemgetter(1), reverse=True)
        weight = np.mean([ item[1] for item in sorted_idx[0:n_weight] ])
        print("* T %s) weight: %0.2f" % (topic, weight), end=' ')
        for item in sorted_idx[0:n_out-1]:
            print( " %0.3f*%s"  % (item[1] , terms[item[0]]) , end=' ')
        print()

# %%
def plot_clusters(svdX, y_pred, centers):
    plt.style.use('fivethirtyeight')
    f, ax1 = plt.subplots(1, 1, figsize=( 16, 8), facecolor='white')
    ax1.set_xlabel("")
    ax1.set_ylabel("")
    ax1.set_title("K-Means")
    # Only plots the first 2 dimensions of the svdX matrix
    ax1.scatter(svdX[:,0], svdX[:,1], c=y_pred, cmap=plt.cm.Paired, s=45)
    ax1.scatter(centers[:, 0], centers[:, 1], marker='o', c="black", alpha=1, s=150)
    ax1.axis('off')
    plt.show()

# %% [markdown]
# ### Starter Code & Pre-processing

# %%
conn = pymongo.MongoClient("mongodb://localhost:27017/")

db = conn['stack_overflow']

ques_col = db.get_collection('questions')

# %%
n_samp = 250000

D = ques_col.find({}, no_cursor_timeout=True).limit(n_samp)

# for i, doc in tqdm(enumerate(D)):
    
#     update = {'clean_aa': clean_text(doc['accepted_answer']),
#           'clean_qt': clean_text(doc['question_title']),
#           'clean_qb': clean_text(doc['question_body']),
#           'clean_tg': clean_text(doc['tags'])}
    
#     ques_col.update_one(
#         {'_id': ObjectId(doc['_id'])},
#         { "$set":update })



def clean_text_db(doc):
    
    update = {'clean_aa': clean_text(doc['accepted_answer']),
          'clean_qt': clean_text(doc['question_title']),
          'clean_qb': clean_text(doc['question_body']),
          'clean_tg': clean_text(doc['tags'])}
        
    ques_col.update_one(
        {'_id': ObjectId(doc['_id'])},
        { "$set":update })
    
    return 'done'

# from multiprocessing.pool import ThreadPool as Pool

pool = multiprocessing.Pool(8)

pool.map(clean_text_db, D)
# Out:
# 250000it [16:16, 256.08it/s]

# %%
multiprocessing.cpu_count()
# Out:
# 12

# %%
token_frequency = defaultdict(int)

# %%
n_samp = 5000
docs = ques_col.find({}, no_cursor_timeout=True).limit(n_samp)

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

for doc in docs:
    for token in doc['clean_aa'].split(" "):
        token_frequency[token] += 1

# %%
docs = ques_col.find({}, no_cursor_timeout=True).limit(n_samp)

# %%
documents = [ [token for token in doc['clean_aa'].split(" ") if token_frequency[token] > 1]
                for doc in docs  ]

# %%
dictionary = corpora.Dictionary(documents)
dictionary.compactify()
dictionary.save('stack_of.dict')
print(dictionary)
# Out:
# Dictionary(6292 unique tokens: ['actually', 'better', 'call', 'changes', 'could']...)

# %%
corpus = [dictionary.doc2bow(doc) for doc in documents]
corpora.MmCorpus.serialize('stack_of.mm', corpus)

# %%
dictionary = corpora.Dictionary.load("stack_of.dict")
corpus = corpora.MmCorpus("stack_of.mm")

# %% [markdown]
# ### LDA

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in documents]
bow_corpus[20]
# Out:
# [(37, 1),
#  (40, 1),
#  (75, 1),
#  (191, 1),
#  (202, 3),
#  (220, 2),
#  (240, 1),
#  (241, 1),
#  (242, 1),
#  (243, 1),
#  (244, 2),
#  (245, 1),
#  (246, 1),
#  (247, 1),
#  (248, 3),
#  (249, 1)]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=5, workers=8)

lda_model.save('lda_model25.lda')

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 actually
# 1 better
# 2 call
# 3 changes
# 4 could
# 5 datatable
# 6 dom
# 7 either
# 8 href
# 9 https
# 10 loop

# %%
bow_doc_20 = bow_corpus[20]
for i in range(len(bow_doc_20)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_20[i][0], 
                                               dictionary[bow_doc_20[i][0]], bow_doc_20[i][1]))
# Out:
# Word 37 ("code") appears 1 time.
# Word 40 ("pre") appears 1 time.
# Word 75 ("class") appears 1 time.
# Word 191 ("configuration") appears 1 time.
# Word 202 ("classes") appears 3 time.
# Word 220 ("public") appears 2 time.
# Word 240 ("avoid") appears 1 time.
# Word 241 ("declaring") appears 1 time.
# Word 242 ("first") appears 1 time.
# Word 243 ("generally") appears 1 time.
# Word 244 ("iconfiguration") appears 2 time.
# Word 245 ("inside") appears 1 time.
# Word 246 ("private") appears 1 time.
# Word 247 ("readonly") appears 1 time.
# Word 248 ("searches") appears 3 time.
# Word 249 ("take") appears 1 time.

# %%
unseen_document = 'How to add a smooth transition effect'

bow_vector = dictionary.doc2bow(clean_text(unseen_document).split(" "))
for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.8198499083518982	 Topic: 0.228*"code" + 0.034*"pre" + 0.014*"use" + 0.010*"quot" + 0.008*"function"
# Score: 0.020019683986902237	 Topic: 0.119*"code" + 0.096*"quot" + 0.047*"pre" + 0.024*"data" + 0.020*"class"
# Score: 0.020017428323626518	 Topic: 0.036*"https" + 0.035*"code" + 0.030*"href" + 0.025*"rel" + 0.025*"nofollow"
# Score: 0.020017286762595177	 Topic: 0.108*"code" + 0.068*"quot" + 0.036*"pre" + 0.007*"need" + 0.007*"app"
# Score: 0.02001643180847168	 Topic: 0.125*"code" + 0.049*"pre" + 0.016*"class" + 0.011*"int" + 0.010*"override"
# Score: 0.020016295835375786	 Topic: 0.048*"strong" + 0.022*"code" + 0.020*"https" + 0.019*"com" + 0.016*"href"
# Score: 0.020016035065054893	 Topic: 0.038*"code" + 0.033*"href" + 0.032*"https" + 0.028*"rel" + 0.026*"noreferrer"
# Score: 0.020015772432088852	 Topic: 0.066*"code" + 0.020*"pre" + 0.016*"https" + 0.014*"href" + 0.011*"use"
# Score: 0.020015636458992958	 Topic: 0.061*"quot" + 0.029*"code" + 0.017*"strong" + 0.011*"https" + 0.011*"pre"
# Score: 0.020015517249703407	 Topic: 0.056*"code" + 0.020*"pre" + 0.014*"import" + 0.012*"quot" + 0.011*"blockquote"

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.119*"code" + 0.096*"quot" + 0.047*"pre" + 0.024*"data" + 0.020*"class" + 0.013*"lang" + 0.011*"div" + 0.011*"snippet" + 0.009*"false" + 0.008*"use"'),
#  (1,
#   '0.061*"quot" + 0.029*"code" + 0.017*"strong" + 0.011*"https" + 0.011*"pre" + 0.011*"href" + 0.010*"use" + 0.010*"string" + 0.009*"one" + 0.007*"com"'),
#  (2,
#   '0.108*"code" + 0.068*"quot" + 0.036*"pre" + 0.007*"need" + 0.007*"app" + 0.006*"date" + 0.006*"function" + 0.006*"data" + 0.006*"use" + 0.006*"name"'),
#  (3,
#   '0.038*"code" + 0.033*"href" + 0.032*"https" + 0.028*"rel" + 0.026*"noreferrer" + 0.026*"nofollow" + 0.020*"com" + 0.019*"docs" + 0.015*"pandas" + 0.014*"html"'),
#  (4,
#   '0.056*"code" + 0.020*"pre" + 0.014*"import" + 0.012*"quot" + 0.011*"blockquote" + 0.010*"use" + 0.009*"set" + 0.008*"file" + 0.008*"href" + 0.007*"https"'),
#  (5,
#   '0.048*"strong" + 0.022*"code" + 0.020*"https" + 0.019*"com" + 0.016*"href" + 0.011*"pre" + 0.011*"using" + 0.009*"rel" + 0.008*"nofollow" + 0.007*"like"'),
#  (6,
#   '0.066*"code" + 0.020*"pre" + 0.016*"https" + 0.014*"href" + 0.011*"use" + 0.010*"com" + 0.009*"rel" + 0.007*"nofollow" + 0.007*"noreferrer" + 0.007*"quot"'),
#  (7,
#   '0.228*"code" + 0.034*"pre" + 0.014*"use" + 0.010*"quot" + 0.008*"function" + 0.006*"value" + 0.006*"data" + 0.006*"using" + 0.006*"need" + 0.005*"strong"'),
#  (8,
#   '0.125*"code" + 0.049*"pre" + 0.016*"class" + 0.011*"int" + 0.010*"override" + 0.009*"prettyprint" + 0.009*"lang" + 0.008*"like" + 0.008*"use" + 0.007*"public"'),
#  (9,
#   '0.036*"https" + 0.035*"code" + 0.030*"href" + 0.025*"rel" + 0.025*"nofollow" + 0.024*"noreferrer" + 0.022*"pre" + 0.016*"use" + 0.015*"org" + 0.014*"quot"')]

# %%
# pyLDAvis.enable_notebook()

# %%
# followers_data =  gensimvis.prepare(lda_model, bow_corpus, dictionary)
# pyLDAvis.display(followers_data)

# %%
docs_per_topic=get_docs_per_topic(lda_model)
# for i in range(10):
#     docs_per_topic[i].sort(reverse=True,key=itemgetter(1))
get_answer_lda('How to add a smooth transition in HTML with CSS?',docs_per_topic, 'lda_model25.lda')
# Out:
# '"<p>Replace this:</p> <pre><code>with open(&quot;blah.txt&quot;, &quot;w&quot;) as f:     f.write(str(df)) </code></pre> <p>With this:</p> <pre><code>df.to_csv(&quot;blah.txt&quot;, index=False) </code></pre> <p>If you want to control more aspects of the '

# %%
# lda_model.save('lda_model25.lda')
# lda_model=models.LdaModel.load('lda_model.lda')

# %% [markdown]
# ### LSI

# %%
tfidf = gensim.models.TfidfModel(corpus, smartirs='npu')
corpus_tfidf = tfidf[corpus]

# %%
lsa_model = gensim.models.LsiModel(corpus_tfidf, num_topics=10, distributed=True)

# %%
docs_per_topic=get_docs_per_topic(lda_model)
# for i in range(10):
#     docs_per_topic[i].sort(reverse=True,key=itemgetter(1))
get_answer_lsa('How to add a smooth transition in HTML with CSS?',docs_per_topic,lsa_model, 'lda_model25.lda')
# Out:
# '<p>First up take those classes out of searches (generally you should avoid declaring classes inside other classes):</p> <pre><code>public class Searches {     private readonly IConfiguration _config;      public Searches(IConfiguration configuration)     '

# %%
#TruncatedSVD

# %%
topic = None
n_out = 7
n_weight = 5
n_samp = 250000
n_components = 10     
n_clusters = 3

# %%
docs = ques_col.find({}, no_cursor_timeout=True).limit(n_samp)

documents = [ [token for token in doc['clean_aa'].split(" ") if token_frequency[token] > 1]
                for doc in docs  ]
tokenized   = [ ' '.join(doc) for doc in documents ]

# %%
vectorizer  = TfidfVectorizer(max_df=0.9,  min_df=6,
                            max_features=500, use_idf=True,
                            strip_accents='ascii')

# %%
X = vectorizer.fit_transform(tokenized)

svd  = TruncatedSVD(n_components, random_state= 10)
svdX = svd.fit_transform(X)

# %%
km = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=100, n_init=4,
                verbose=False, random_state= 10)
km.fit(svdX)
# Out:
# KMeans(max_iter=100, n_clusters=3, n_init=4, random_state=10, verbose=False)

# %%
metrics.silhouette_score(svdX, km.labels_, sample_size=1000)
# Out:
# 0.21267346851725286

# %%
terms = vectorizer.get_feature_names()

# %%
get_lsa_topics(svd, terms, n_components)
# Out:
# T0)  0.822*code  0.273*pre  0.203*quot  0.119*use  0.097*class  0.094*data
# T1)  0.924*quot  0.169*code  0.146*https  0.130*href  0.118*rel  0.116*nofollow
# T2)  0.408*https  0.357*href  0.321*rel  0.312*nofollow  0.306*noreferrer  0.291*com
# T3)  0.580*data  0.375*class  0.352*snippet  0.287*div  0.268*false  0.266*lang
# T4)  0.974*strong  0.104*code  0.065*blockquote  0.049*https  0.046*rel  0.046*noreferrer
# T5)  0.604*pre  0.334*code  0.245*data  0.226*override  0.214*prettyprint  0.194*import
# T6)  0.327*data  0.323*class  0.292*override  0.286*prettyprint  0.262*lang  0.215*blockquote
# T7)  0.504*pre  0.395*blockquote  0.256*class  0.213*override  0.203*prettyprint  0.191*data
# T8)  0.432*com  0.374*org  0.281*html  0.272*pandas  0.234*github  0.230*docs
# T9)  0.753*import  0.282*select  0.209*file  0.188*function  0.154*string  0.124*pandas

# %%
y_pred  = km.predict(svdX)
centers = km.cluster_centers_

plot_clusters(svdX, y_pred, centers)

# %% [markdown]
# ### Coherence Scores For LSA and LDA

# %%
print('\nPerplexity of LDA: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=documents, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score of LDA: ', coherence_lda)
# Out:
# Perplexity of LDA:  -6.944491202961046
#
# Coherence Score of LDA:  0.33780507310765034

# %%
cm = CoherenceModel(model=lsa_model, corpus=bow_corpus, coherence='u_mass', dictionary=dictionary)

# %%
print('Coherence Score of LSI/LSA:',cm.get_coherence())
# Out:
# Coherence Score of LSI/LSA: -6.40499475120595

# %% [markdown]
# ### GUI Code

# %%
pip install anvil-uplink

# %%
import anvil.server

anvil.server.connect("JFDOZJPEIPFWAAHOHU2572M3-FLFKW5RP3WDNE4AZ")

# Anvil Link: https://flfkw5rp3wdne4az.anvil.app/OICRXKVGDG7GXU3RYXSNYU3Q
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER

# %%
@anvil.server.callable
def get_answer_gui(q_text):
    
    lda_model=models.LdaModel.load('lda_model25.lda')
    
    docs_per_topic = get_docs_per_topic(lda_model)
        
    dictionary = corpora.Dictionary.load("stack_of.dict")
        
    unseen_doc = dictionary.doc2bow(clean_text(q_text).split(" "))
        
    vector = lda_model[unseen_doc]
        
    vector.sort(key=itemgetter(1), reverse=True)
    
    topic_id = vector[0][0]
    
    doc_id = docs_per_topic[topic_id][0][0]
    
    conn = pymongo.MongoClient("mongodb://localhost:27017/")

    db = conn['stack_overflow']

    ques_col = db.get_collection('questions')
    
    docs = ques_col.find({}, no_cursor_timeout=True).limit(5000)
    
    for doc in docs:
        for token in doc['clean_aa'].split(" "):
            token_frequency[token] += 1
        
    docs = ques_col.find({}, no_cursor_timeout=True).limit(5000)
    
    documents = [ [token for token in doc['clean_aa'].split(" ") if token_frequency[token] > 1]
                for doc in docs  ]
    
    answer = ques_col.find_one({ "clean_aa": ' '.join(documents[doc_id])})['accepted_answer']
    
    return answer

anvil.server.wait_forever()
# Out:
# Anvil websocket closed (code 1006, reason=Going away)
# Reconnecting Anvil Uplink...
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER
# Anvil websocket closed (code 1006, reason=Going away)
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "C:\Users\91939\.conda\envs\dbms\lib\site-packages\anvil\server.py", line 403, in call
#     return _do_call(args, kwargs, fn_name=fn_name)
#   File "C:\Users\91939\.conda\envs\dbms\lib\site-packages\anvil\server.py", line 395, in _do_call
#     return _threaded_server.do_call(args, kwargs, fn_name=fn_name, live_object=live_object)
#   File "C:\Users\91939\.conda\envs\dbms\lib\site-packages\anvil\_threaded_server.py", line 423, in do_call
#     raise error_from_server
# anvil._server.AnvilWrappedError: 'Connection to Anvil Uplink server lost'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\91939\.conda\envs\dbms\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\91939\.conda\envs\dbms\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\91939\.conda\envs\dbms\lib\site-packages\anvil\server.py", line 206, in heartbeat_until_reopened
#     call("anvil.private.echo", "keep-alive")
#   File "C:\Users\91939\.conda\envs\dbms\lib\site-packages\anvil\server.py", line 406, in call
#     raise _server._deserialise_exception(e.error_obj)
# anvil._server.AnvilWrappedError: 'Connection to Anvil Uplink server lost'
# Reconnecting Anvil Uplink...
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27188/1283952204.py in <module>
#      39     return answer
#      40
# ---> 41 anvil.server.wait_forever()
#
# ~\.conda\envs\dbms\lib\site-packages\anvil\server.py in wait_forever()
#     430     _get_connection()
#     431     while True:
# --> 432         time.sleep(1)
#
# KeyboardInterrupt:
